# %%
from pathlib import Path

from matflow import load_workflow

import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage
from matplotlib import gridspec
from PIL import Image
import pandas as pd
import csvkit

# %matplotlib inline

# %% [markdown]
# # Load workflow

# %%
#A --------------------------------------------------
#HRDIC A3 full 10um
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-11-170500')

#HRDIC A3 before reduced area 10um
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-23-123252')

#HRDIC A3 full 3.5um
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-23-123701')

#HRDIC A3 before reduced area 3.5um
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-23-123409')

#HRDIC A3 before reduced area 0.5um 
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-23-123529')

#B --------------------------------------------------
#HRDIC B1 after 
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-03-07-165420')

#HRDIC B2 before area 1
workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-11-104818')

#C --------------------------------------------------

#D --------------------------------------------------
#HRDIC D1 full
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-11-171010')

#HRDIC D1 before area1
#workflow = load_workflow('E:/Matflow_exports/RVE_extrusion_2022-04-11-170830')


sim_task = workflow.tasks.simulate_volume_element_loading
vol_elem_resp = sim_task.elements[0].outputs.volume_element_response
# Out:
# Loading matflow config from C:\Users\mbgm5pc3\.matflow\config.yml
# Loading task schemas from 1 file(s)...OK!
# Loading software definitions from 1 file(s)...OK!
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\matflow\config.py:100: PendingDeprecationWarning:
# safe_load will be removed, use
#
#   yaml=YAML(typ='safe', pure=True)
#   yaml.load(...)
#
# instead
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\ruamel\yaml\main.py:1105: PendingDeprecationWarning:
# load will be removed, use
#
#   yaml=YAML(typ='unsafe', pure=True)
#   yaml.load(...)
#
# instead
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# ...
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.
# C:\Users\mbgm5pc3\Anaconda3\envs\matflow_env\lib\site-packages\h5py\_hl\dataset.py:541: DeprecationWarning: Passing None into shape arguments as an alias for () is deprecated.

# %% [markdown]
# # Input experimental HRDIC data
# Use .csv

# %%
experimental_data = pd.read_csv (r'SampleB1_test.csv') # files needs to be in the same folder

# %%
elongation = experimental_data['Elongation (Âµm)']
force = experimental_data['Force (N)']

# %%
elongation = elongation.to_numpy()
force = force.to_numpy()

# %%
width = 3e-3      #m 
height = 1.8e-3   #m                   ----varibale---- 
length = 10e+3    #um
#length must be in microns as the elongation is measured in microns

area = width * height
eng_stress = (force / area) #Pa
eng_strain = elongation / length #No units

# %%
 plt.figure()
plt.plot(eng_strain, eng_stress/1e6)
#plt.plot(mean_strain, mean_stress/1e6)

plt.xlabel('Strain')
plt.ylabel('Stress (MPa)')
#plt.xlim([0, None])
#plt.ylim([, None])
#plt.savefig(r'stress_strain_curve_experimental.png')

# %%
eng_stress_truncated = eng_stress[20000:60000]
eng_strain_truncated = eng_strain[20000:60000]

# %%
eng_stress_truncated
eng_strain_truncated

plt.figure()
plt.plot(eng_strain, eng_stress/1e6, label = 'Experimental')
plt.plot(mean_strain[:, 0, 0], mean_stress[:, 0, 0]/1e6, label = 'Simulated')
#plt.plot(mean_strain, mean_stress/1e6)

plt.xlabel('Strain')
plt.ylabel('Stress (MPa)')
plt.legend()
#plt.xlim([0, None])
#plt.ylim([0, None])

#plt.savefig(r'stress_strain_curve_simulated_vs_experimental.png')

# %%
len(eng_stress)
# Out:
# 66642

# %%
#Correct for the compliances

# %%
workflow.tasks
# Out:
# (Task(name='load_microstructure', method='EBSD', software='defdap'), Task(name='generate_volume_element', method='extrusion', software='damask'), Task(name='modify_volume_element', method='add_buffer_zones', software='damask'), Task(name='visualise_volume_element', method='VTK', software='damask'), Task(name='generate_load_case', method='uniaxial', software='formable'), Task(name='simulate_volume_element_loading', method='CP_FFT', software='damask'))

# %% [markdown]
# # Plot simulated stress strain curve

# %%
mean_strain = vol_elem_resp['phase_data']['vol_avg_strain']['data']
mean_stress = vol_elem_resp['phase_data']['vol_avg_stress']['data']

#mean_strain = vol_elem_resp['phase_data']['vol_avg_equivalent_strain']['data']
#mean_stress = vol_elem_resp['phase_data']['vol_avg_equivalent_stress']['data']

# %%
mean_stress.shape
# Out:
# (11, 3, 3)

# %%
'''import csv

with open('new +45x','w') as f:
    writer = csv.writer(f)
    
    writer.writerow(mean_strain)
    writer.writerow(mean_stress)'''
# Out:
# "import csv\n\nwith open('new +45x','w') as f:\n    writer = csv.writer(f)\n    \n    writer.writerow(mean_strain)\n    writer.writerow(mean_stress)"

# %%
plt.figure()
plt.plot(mean_strain[:, 0, 0], mean_stress[:, 0, 0]/1e6)
#plt.plot(mean_strain, mean_stress/1e6)

plt.xlabel('Strain')
plt.ylabel('Stress (MPa)')
plt.xlim([0, None])
plt.ylim([0, None])

#plt.savefig(r'stress_strain_curve_random orientation.png')
# Out:
# (0.0, 957.2756744645386)

# %% [markdown]
# # Plot stress map

# %%
stress = vol_elem_resp['field_data']['sigma']
print(stress['meta']['increments'])

stress = stress['data']
print(stress.shape)
# Out:
# [100]
# (1, 996, 901, 10, 3, 3)

# %%
'''alpha = (np.pi/ 180) * -45
beta = (np.pi/ 180) * -45

rotation_matrix = [np.cos(alpha), -np.sin(beta), 0], [ np.sin(alpha), np.cos(beta), 0],[ 0, 0, 1]


partly_rotated_stress = np.einsum('...ij,jk->...ik', stress, rotation_matrix)
rotated_stress = np.einsum('...ij,ik->...kj',partly_rotated_stress, rotation_matrix)
# Out:
#   Input In [8]
#     rotated_stress = np.einsum('...ij,ik->...kj',partly_rotated_stress, rotation_matrix)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
inc = 0
z_layer = 4
tensor_comp = (0, 0)
buff_size_xy = (4, 4)

map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
) + tensor_comp

plt.figure()#figsize=(18,10),dpi=1600
plt.imshow(stress[map_slice].T*1e-6,vmin=700, vmax =1200)#vmin=550, vmax =650
plt.colorbar(label='Stress (MPa)')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
#plt.savefig(r'stress_HRDIC_B2_before_area_1.png')

# %% [markdown]
# # Plot strain map

# %%
strain = vol_elem_resp['field_data']['epsilon_U^2(F)']
print(strain['meta']['increments'])
strain = strain['data']
print(strain.shape)
# Out:
# [100]
# (1, 996, 901, 10, 3, 3)

# %%
'''alpha = (np.pi/ 180) * -45
beta = (np.pi/ 180) * -45

rotation_matrix = [np.cos(alpha), -np.sin(beta), 0], [ np.sin(alpha), np.cos(beta), 0],[ 0, 0, 1]


partly_rotated_strain = np.einsum('...ij,jk->...ik', strain, rotation_matrix)
rotated_strain = np.einsum('...ij,ik->...kj',partly_rotated_strain, rotation_matrix)
# Out:
#   Input In [8]
#     rotated_strain = np.einsum('...ij,ik->...kj',partly_rotated_strain, rotation_matrix)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
inc = 0
z_layer = 4
tensor_comp = (0, 0)
buff_size_xy = (4, 4)

map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
) + tensor_comp

plt.figure() #figsize=(12,6),dpi=1200
plt.imshow(strain[map_slice].T,vmin=0.005,vmax=0.015)
plt.colorbar(label='Strain')
plt.xticks([])
plt.yticks([])


plt.tight_layout()
#plt.savefig(r'strain_HRDIC_B2_before_area_1.png')

# %% [markdown]
# # Plot plastic strain map

# %%
plastic_strain = vol_elem_resp['field_data']['epsilon_U^2(F_p)']
print(plastic_strain['meta']['increments'])
plastic_strain = plastic_strain['data']
print(plastic_strain.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 plastic_strain = vol_elem_resp['field_data']['epsilon_U^2(F_p)']
#       2 print(plastic_strain['meta']['increments'])
#       3 plastic_strain = plastic_strain['data']
#
# KeyError: 'epsilon_U^2(F_p)'

# %%
alpha = (np.pi/ 180) * +45
beta = (np.pi/ 180) * +45

rotation_matrix = [np.cos(alpha), -np.sin(beta), 0], [ np.sin(alpha), np.cos(beta), 0],[ 0, 0, 1]


partly_rotated_plastic_strain = np.einsum('...ij,jk->...ik', plastic_strain, rotation_matrix)
rotated_plastic_strain = np.einsum('...ij,ik->...kj',partly_rotated_plastic_strain, rotation_matrix)

# %%
inc = 0
z_layer = 2
tensor_comp = (0, 0)
buff_size_xy = (4, 4)

map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
) + tensor_comp

plt.figure()
plt.imshow(rotated_plastic_strain[map_slice].T,vmin=0,vmax=0.00001)
plt.colorbar(label='Plastic Strain')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
#plt.savefig(r'plastic_strain_-45x.png')

# %%
def plot_profile(def_map,start_point,end_point):
    x0, y0  = start_point[0], start_point[1] # These are in _pixel_ coordinates!!
    x1, y1 = end_point[0], end_point[1]
    profile_length=np.sqrt((y1-y0)**2+(x1-x0)**2)
    num = np.round(int(profile_length))
    x, y = np.linspace(x0, x1, num), np.linspace(y0, y1, num)

    # Extract the values along the line, using cubic interpolation
    zi = scipy.ndimage.map_coordinates(np.transpose(def_map), np.vstack((x,y)))
    plt.figure(figsize=(10,3))
    gs = gridspec.GridSpec(1, 2, height_ratios=[1]) 
    ax0=plt.subplot(gs[0])
    ax1=plt.subplot(gs[1])
    ax0.imshow(def_map,vmin=-0.00,vmax=0.005,interpolation='bilinear',cmap='viridis');
    ax0.plot([x0, x1], [y0, y1], 'rx-',lw=2);
    ax0.axis('image');
    ax1.plot(zi)
    ax1.axis('tight')

# %%
plot_profile(plastic_strain[map_slice].T,[200,100],[1100,100])
plt.savefig(r'plastic_strain_measurement_test.png')

# %% [markdown]
# # Shear on each slip system

# %%
shear = vol_elem_resp['field_data']['gamma_sl']
print(shear['meta']['increments'])
shear = shear['data']
print(shear.shape)
# Out:
# [50]
# (1, 1246, 836, 10, 12)

# %%
inc = 0
z_layer = 2
tensor_comp = (0,)
buff_size_xy = (4, 4)

map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
) + tensor_comp

#np.amax(shear[map_slice])

plt.figure()
plt.imshow(shear[map_slice].T)
plt.colorbar(label='Shear')
plt.xticks([])
plt.yticks([])

plt.tight_layout()

# %%
inc = 0
z_layer = 2
buff_size_xy = (4, 4)
map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
)
print(shear[map_slice].shape)  # should be 3 numbers (x, y, 12), check his 
max_shear = np.max(shear[map_slice], axis=2)
plt.figure()
plt.imshow(max_shear.T,vmin=0,vmax=0.00005)
plt.colorbar(label='Shear')
plt.xticks([])
plt.yticks([])
plt.tight_layout()

#plt.savefig(r'shear_+45x.png')
# Out:
# (1238, 828, 12)

# %%
map_slice
# Out:
# (0, slice(4, -4, None), slice(4, -4, None), 2)

# %%
print(shear[map_slice].shape)
# Out:
# (1238, 828, 12)

# %%
inc = 0
z_layer = 2
tensor_comp = (2,)
buff_size_xy = (4, 4)

map_slice = (
    inc, 
    slice(buff_size_xy[0], -buff_size_xy[0]), 
    slice(buff_size_xy[1], -buff_size_xy[1]), 
    z_layer
) + tensor_comp

apple = np.amax(shear[map_slice])

# %%
#    '''plt.figure()
#    plt.imshow(shear[map_slice].T,vmin=0,vmax=0.0000005)
#    plt.colorbar(label='Shear')
#    plt.xticks([])
#    plt.yticks([])
#    plt.tight_layout()'''

# %%
plt.hist(shear[map_slice].flatten(),range=(0,2e-7))
# Out:
# (array([475000.,  36537.,  24085.,  18301.,  16431.,  14020.,  12552.,
#          11357.,  10637.,   9950.]),
#  array([0.0e+00, 2.0e-08, 4.0e-08, 6.0e-08, 8.0e-08, 1.0e-07, 1.2e-07,
#         1.4e-07, 1.6e-07, 1.8e-07, 2.0e-07]),
#  <BarContainer object of 10 artists>)

# %%
np.mean(shear[map_slice])
# Out:
# 4.27689276387974e-05

# %%
N = range(0,12,1)
shear_values=[]
for i in N:
    inc = 0
    z_layer = 2
    tensor_comp = (i,)
    buff_size_xy = (4, 4)

    map_slice = (
        inc, 
        slice(buff_size_xy[0], -buff_size_xy[0]), 
        slice(buff_size_xy[1], -buff_size_xy[1]), 
        z_layer
    ) + tensor_comp

    apple = np.amax(shear[map_slice])
    shear_values.append(np.mean(shear[map_slice]))


shear_table=pd.DataFrame(shear_values)

# %%
shear_table
# Out:
#                0
# 0   2.075788e-05
# 1   1.013736e-05
# 2   4.163537e-06
# 3   1.289807e-07
# 4   9.293126e-08
# 5   9.321683e-08
# 6   5.149395e-11
# 7   3.114470e-11
# 8   1.738929e-11
# 9   1.549523e-11
# 10  5.379516e-11
# 11  6.649015e-11

# %% [markdown]
# # Plot grain average stress

# %%
stress_grain = vol_elem_resp['grain_data']['sigma']
print(stress_grain['meta']['increments'])
stress_grain = stress_grain['data']
print(stress_grain.shape)
# Out:
# [50]
# (1, 29270, 3, 3)

# %%
tensor_comp = (0, 0)

plt.figure()
for inc in range(1):
    # Remove last 2 grain of air and iso Ti
    data_slice = (inc, slice(None, -2)) + tensor_comp

    plt.hist(stress_grain[data_slice]*1e-6, histtype='step', density=True, label=f'inc {inc}')
    
plt.legend()
plt.xlabel('Stress (MPa)')
plt.ylabel('Normalised frequency')
# Out:
# Text(0, 0.5, 'Normalised frequency')

# %% [markdown]
# # Plot grain average orientations

# %%
from defdap.quat import Quat

# %%
ori_grain = vol_elem_resp['grain_data']['O']
print(ori_grain['meta']['increments'])
ori_grain = ori_grain['data']['quaternions']
print(ori_grain.shape)
# Out:
# [50]
# (1, 29270, 4)

# %%
# Swap to P=+1
ori_grain[:, :, 1:] *= -1
# Remove last 2 grain of air and iso Ti
ori_grain = ori_grain[:, :-2, :]

# %%
quat_grain = np.empty(ori_grain.shape[:-1], dtype=Quat)

for idx in np.ndindex(quat_grain.shape):
    quat_grain[idx] = Quat(ori_grain[idx])

# %%
inc = 0
direction = np.array([1, 0, 0])

Quat.plotIPF(quat_grain[inc], direction, 'cubic')

# %%
vol_elem_resp['field_data'].keys()
# Out:
# dict_keys(['epsilon_U^2(F)', 'sigma', 'O', 'u_n', 'epsilon_U^2(F_p)', 'gamma_sl'])

# %%
alpha = (np.pi/ 180) * 45
beta = (np.pi/ 180) * 45

rotation_matrix = [np.cos(alpha), -np.sin(beta), 0], [ np.sin(alpha), np.cos(beta), 0],[ 0, 0, 1]
rotation_matrix = np.matrix(rotation_matrix)
rotation_matrix

trasposed_rotation_matrix =rotation_matrix.transpose()
trasposed_rotation_matrix
# Out:
# matrix([[ 0.70710678,  0.70710678,  0.        ],
#         [-0.70710678,  0.70710678,  0.        ],
#         [ 0.        ,  0.        ,  1.        ]])

# %%
a = np.matrix('1 2; 3 4')

# %%
a
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
sigma12 = -np.sin(beta)

# %%
profile_length=np.sqrt((150-83)**2+(72-64)**2)
num = np.round(int(profile_length))
x, y = np.linspace(72, 64, num), np.linspace(150, 83, num)

# %%
x, y
# Out:
# (array([72.        , 71.87878788, 71.75757576, 71.63636364, 71.51515152,
#         71.39393939, 71.27272727, 71.15151515, 71.03030303, 70.90909091,
#         70.78787879, 70.66666667, 70.54545455, 70.42424242, 70.3030303 ,
#         70.18181818, 70.06060606, 69.93939394, 69.81818182, 69.6969697 ,
#         69.57575758, 69.45454545, 69.33333333, 69.21212121, 69.09090909,
#         68.96969697, 68.84848485, 68.72727273, 68.60606061, 68.48484848,
#         68.36363636, 68.24242424, 68.12121212, 68.        , 67.87878788,
#         67.75757576, 67.63636364, 67.51515152, 67.39393939, 67.27272727,
#         67.15151515, 67.03030303, 66.90909091, 66.78787879, 66.66666667,
#         66.54545455, 66.42424242, 66.3030303 , 66.18181818, 66.06060606,
#         65.93939394, 65.81818182, 65.6969697 , 65.57575758, 65.45454545,
#         65.33333333, 65.21212121, 65.09090909, 64.96969697, 64.84848485,
#         64.72727273, 64.60606061, 64.48484848, 64.36363636, 64.24242424,
#         64.12121212, 64.        ]),
#  array([150.        , 148.98484848, 147.96969697, 146.95454545,
#         145.93939394, 144.92424242, 143.90909091, 142.89393939,
#         141.87878788, 140.86363636, 139.84848485, 138.83333333,
#         137.81818182, 136.8030303 , 135.78787879, 134.77272727,
#         133.75757576, 132.74242424, 131.72727273, 130.71212121,
#         129.6969697 , 128.68181818, 127.66666667, 126.65151515,
#         125.63636364, 124.62121212, 123.60606061, 122.59090909,
#         121.57575758, 120.56060606, 119.54545455, 118.53030303,
#         117.51515152, 116.5       , 115.48484848, 114.46969697,
#         113.45454545, 112.43939394, 111.42424242, 110.40909091,
#         109.39393939, 108.37878788, 107.36363636, 106.34848485,
#         105.33333333, 104.31818182, 103.3030303 , 102.28787879,
#         101.27272727, 100.25757576,  99.24242424,  98.22727273,
#          97.21212121,  96.1969697 ,  95.18181818,  94.16666667,
#          93.15151515,  92.13636364,  91.12121212,  90.10606061,
#          89.09090909,  88.07575758,  87.06060606,  86.04545455,
#          85.03030303,  84.01515152,  83.        ]))
